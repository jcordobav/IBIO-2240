# %% [markdown]
# <a href="https://colab.research.google.com/github/jcordobav/IBIO-2240/blob/Cordoba/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('soy biomédica')

# %%
print('Me llamo Juan Jose')
